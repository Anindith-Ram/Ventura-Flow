# %%
import torch
free = torch.cuda.mem_get_info()[0] / 1e9
total = torch.cuda.get_device_properties(0).total_memory / 1e9
print(f"Free: {free:.1f} GB / {total:.1f} GB")
# Should show ~39 GB free after a fresh restart
# Out:
# Free: 42.0 GB / 42.4 GB

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Ventura-Flow
# !python pipeline.py --dry-run  # verify file is updated first
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Ventura-Flow
# [04:33:10] Loaded: sample_input.json -- 'Auto-IDAES: Autonomous Generation of Converged Process Models via Visu'
#
# ...
# [DRY RUN] BULL_RESEARCHER SYSTEM PROMPT
# ...
#
# You are **SCOUT-BULL** -- a commercial intelligence analyst on the deal team of a techno-optimist deep-tech venture fund. You do not form investment theses. Your job is to find the strongest publicly available evidence that the paper in front of you describes a *commercially significant* breakthrough.
#
# You operate in two phases. The user message will start with one of these headers:
#
# ---
#
# ## PHASE: QUERY_GENERATION
#
# The user will provide the academic paper's structured JSON (title, abstract, methodology, conclusions, data_tables, domain_tags).
#
# Your job: produce **6-8 search queries** targeting the following evidence classes:
# 1. **Total Addressable Market (TAM)**: industry market-size reports, forecasted CAGR, downstream market valuations.
# ...

# %%
import os
os.environ["HF_HOME"] = "/content/drive/MyDrive/Ventura-Flow/hf_cache"
    
# !pip install -r /content/drive/MyDrive/Ventura-Flow/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 58.0 MB/s eta 0:00:0000:0100:01
# ...

# %%
with open("/content/drive/MyDrive/Ventura-Flow/pipeline.py") as f:
    content = f.read()

assert "device=0" in content, "Not synced yet — wait and retry"
print("Synced! Run the pipeline.")
# Out:
# Synced! Run the pipeline.

# %%
# !python pipeline.py
# Out:
# [04:33:38] Loaded: sample_input.json -- 'Auto-IDAES: Autonomous Generation of Converged Process Models via Visu'
# [04:33:38] Run ID: 20260417_043338
# [04:33:52] Loading model: Qwen/Qwen2.5-7B-Instruct (DOWNLOADING -- this may take a while)
# [04:33:52] VRAM available: 42.4 GB
# config.json: 100% 663/663 [00:00<00:00, 2.33MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 27.8kB [00:00, 18.4MB/s]
# ...
# Fetching 4 files: 100% 4/4 [00:47<00:00, 11.98s/it]
# Download complete: 100% 15.2G/15.2G [00:48<00:00, 317MB/s]
# Loading weights: 100% 339/339 [00:06<00:00, 53.60it/s, Materializing param=model.norm.weight]
# generation_config.json: 100% 243/243 [00:00<00:00, 1.05MB/s]
# tokenizer_config.json: 7.30kB [00:00, 11.7MB/s]
# vocab.json: 2.78MB [00:00, 6.39MB/s]
# merges.txt: 1.67MB [00:00, 38.7MB/s]
# tokenizer.json: 7.03MB [00:00, 53.6MB/s]
# [04:34:57] Model loaded in 65.0s
# [04:34:57] [BULL_RESEARCHER] Generating search queries...
# ...
